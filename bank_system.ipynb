# %%
creatingAccount=()

# %%
balance={'balance':0.00,}

# %%
pins={'T_pin':1234,'M_pin':3333}

# %%
def create_account():
    name=input('enter your full name').title()
    phone=input('enter your phone number')
    sourceOFMoney=input('enter your source of money')
    location=input('where do you stay')
    amount=float(input('enter amount you recieve each month'))
    properties_you_own=input('enter properties you have e.g cars or house')
    NationalID_No=input('enter your national id number')
    typeOF_card=input('enter type of ATM card you want neither platnum nor classic')
    sex=input('enter your sex M or F')
    creatingAccount=({'name':name,
                     'phone':phone,
                     'sourceOFMoney':sourceOFMoney,
                     'location':location,
                     'amount':amount,
                     'properties_you_own':properties_you_own,
                     'NationalID_No':NationalID_No,
                     'typeOF_card':typeOF_card,
                     'sex':sex})
    if sex=='M':
        print(f'Mr{name} your account has been created and your account number is 1234568 and your M_pin is 3333')
    elif sex=='F':
        print(f'mrs {name} your account has been created  and your account number is 1346890 and your M_pin is 3333')
    else:
        print('enter appropriate information')

# %%
def money_transfer():
    while True:
        print('1.own account')
        print('2.To national bank account')
        print('3.To other bank')
        print('4.To mobile wallet')
        print('0. exit to main menu')
        option=input('enter your option')
        if option==1:
            source_account=input('enter a source account either savings')
            select_to_account=input("enter acount number where you're sending")
            amount=float(input('enter amount in MKW'))
            description=input('enter a transfer description')
            print('\n======money===== transfer========')
            print(f'you have tarnsfered MKW.{amount} to {select_to_account} number')
            print('national bank will not be responsible for wrong transfer' )
        elif option==2:
            while True:
                print('1.other National bank account')
                print('2.To NBM once off')
                print('#. menu')
                option=input('enter option')
                if option==1:
                    recipient_account_No=int(input('enter the account number of the recipient'))
                    recipient_name=input('enter the name of the recipient')
                    phone=input('enter phone number of the recipient')
                    amount=input('enter amount you want to send')
                    print(f' you have sent MKW.{amount} to {recipient_name} his number is {phone} and his account No. is  {recipient_account_No}successfuly')
                elif option==2:
                    source_name_account=input('either savings or something else')
                    Amount=float(input('enter amount you wanna send'))
                    description=input('enter the description of your transaction')
                    print(f'you have transfered MKW.{amount}')
                elif option=='#':
                    print('back to menu')
                    break
                else:
                    print('invalid option entered!')
        elif option==3:
            while True:
                print('1.To other bank Account')
                print('2.To other bank account once off')
                print('3.exit program')
                option=int(input('enter your choice'))
                if option==1:
                    add_recipient_No=input('enter recipient account number:')
                    Amount=float(input('enter amount:.2f'))
                    description=input('enter your description of transfer')
                    print(f'you have sent MKW.{Amount} to {add_recipient_NO} successfuly')
                    print(f'national bank will not be trsponsible for wrong tranfer')
                elif option==2:
                    Bank_name=input('enter bank name your are sending to:')
                    sourceAccount=input('enter source account either savings or else:')
                    Recipient_accountNo=int(input('enter account number:'))
                    Name=input('enter recipient name:').title()
                    phone=input('enter recipient phone number:')
                    Amount=input('enter money you want to send:MKW.')
                    description=input('describe money transaction')
                    print(f'you have sent MKW.{Amount} to {Name} and his bank account is {Recipient_accountNo} successfully')
                elif option==3:
                    print('print program exited')
                    break
                else:
                    print('invalid option!')
        
        elif option==4:
            while True:
                print('1.Mo626 wallet')
                print('2.Airtel Money')
                print('3.TNM number')
                print('4. exit')
                choice=input('')
                if choice==1:
                    Amount=float(input('enter amount:.2f'))
                    account_source=input('enter either savings or something else:')
                    phone=input('enter recipient phone number:')
                    description=input('enter description of money transfer')
                    print(f'you have sent MKW.{Amouny} to phone number {phone} succcessfully')
                    print('\n===NB ill not be responsible for wrong transfer of money===')
                elif choice==2:
                    Account_source=int(input('enter either savinds or something else:'))
                    Amount=float(input('enter amount:.2f'))
                    phone=input('enter airtel phone number:')
                    description=input('enter money transfer description:')
                    print(f'you have sent MKW.{Amount} to {phone} successfully')
                    print('/n=== NB will not be responsible for wrong transaction===')
                elif choice==3:
                    Amount=float(input('enter amount:.2f'))
                    account_source=input('enter either savings or something else:')
                    phone=input('enter recipient TNM  phone number:')
                    description=input('enter description of money transfer')
                    print(f'you have sent MKW.{Amouny} to phone number {phone} succcessfully')
                    print('\n===NB ill not be responsible for wrong transfer of money===')
                elif choice==4:
                    print('exit')
                    break
                else:
                    print('invalid input!')
        else:
            print('invalid input')

# %%
def my_account():
    while True:
        print('1.balance enquiry')
        print('2. min statement')
        print('3.interim staement') 
        print('0.exit program')
        choice=int(input('enter your choice'))
        if choice==1:
            print(f'your balance is MKW.{balance['balance']}')
        elif choice==2:
            print(f'the min statement is  MKW.{balance['balance']}')
        elif choice==3:
            print('the interim statemnt is going to be send to your email shortly')
        elif choice==0:
            print('program exited')
            break
        else:
            print('invalid option!')

# %%
def payments():
    while True:
        print('1.tax payments')
        print('2.DSTV')
        print('3.MASM Payment')
        print('4.Tertialy Education')
        print('5.exit program to main menu')
        option=int(input('enter your option'))
        if option==1:
            source_account=input('enter either savings or something else')
            PRN=input('enter PRN')
            Amount=float(input('enter amount of money:'))
            balance['balance']-=Amount
            print(f'you have paid your tax MKW.{Amount} successfully')
        elif option==2:
            Recipient_number=int(input('enter the number of recipient:'))
            smartcard_number=input('enter smartcard number:')
            print('submitted')
        elif option==3:
            MASM_SCHEME_NUMBER=input('enter your scheme number')
            print('submitted')
        elif option==4:
            source_account=int(input('enter savings or something else'))
            institution=input('enter institution')
            Student_ID=input('enter your  student id')
            Amount=int(input('enter amount:'))
            balance['balance']+=Amount
            print(f"you have paid MKW.{Amount} to {institution} succsessfully")
        elif option==5:
            print('program exited')
            break
        else:
            print('invalid option!')

# %%
def withdrawal():
    while True:
        print('1.cardless withdrawal')
        print('2.Agent direct cash withdrawal')
        print('3.exit')
        option=int(input('enter your option'))
        if option==1:
            while True:
                print('1.Generate for self')
                print('2.Generate for others')
                print('3.view ticket')
                print('4.exit program')
                option=int(input('enter your option'))
                if option==1:
                    Account_source=input('enter either savinds or something else:')
                    select_platfoam=input('either ATM nor AGENT')
                    Amount=float(input('enter amount:.2f'))
                    balance['balance'] -=Amount
                    print(f'you have transfered MKW.{Amount} to {select_platfoam} sucessfully')
                    print('\n==please note that changes will be applicable for this service==')
                elif option==2:
                    Accountsource=input('either savings')
                    platfoam=input('either ATM or AGENT')
                    Amount=float(input('enter amount MKW:'))
                    phone=input('enter phone number')
                    print('\n===please note that changes will be applicable for this services===')
                elif option==3:
                    print('no records were found')
                elif option==4:
                    print('program exited')
                    break
                else:
                    print('wrong input!')

        elif option==2:
            source_account=input('either savings or something else:')
            Agent_code=int(input('enter agent code:'))
            Amount=input(('enter amount MKW:.2f'))
            balance['balance'] -=Amount
            print(f'you have sent MKW>{Amount} to {Agent_code} successfully')
        elif option==3:
            print('program exited')
            break
        else:
            print('invalid option!')

# %%
def loan():
    while True:
        print('1.loan application')
        print('2.loan payment')
        print('3.loan calculation')
        print('4.exit')
        choice=int(input('enter your option'))
        if choice==1:
            loan_type=input('enter type of loan')
            Amount=float(input('enter amount'))
            balance['balance']+=Amount
            print('\n==i accept terms and conditions==')
            print(f'your loan have been granted of MKW.{Amount} that will be paid for three weeks')
        elif choice==2:
            Amount=float(input('enter amount of money'))
            balance['balance']-=Amount
            print(f'you have paid your loan')
        elif choice==3:
            Loan_amount=float(input('enter amount in MKW:.2f'))
            # AnualRate=input('enter your rate')
            months=int(input('enter months taken'))
            SI=Loan_amount*0.2*months
            print(SI)
        elif choice==4:
            print('program exited')
            break
        else:
            print('invalid choice!')

# %%
def deposit():
    Acount_source=input('enter either savings or anything else:')
    Amount=float(input('enter amount'))
    balance['balance'] +=Amount
    if Amount>0:
        print(f'you have deposit MKW.{Amount}')
    elif Amount<0:
        print(f'you cant deposit a negative money')
    else:
        print('invalid input!')

# %%
def top_up():
    while True:
        print('1.Airtel')
        print('2.TNM')
        print('3.exit program')
        choice=int(input('enter your choice'))
        if choice==1:
            sourceAccount=input('enter savings or something else')
            phone=input('enter phone number:')
            Amount=float(input('enter amount MKW:'))
            balance['balance'] -=Amount
            print(f' you have purchased airtime of MKW.{Amount} to {phone} successfully')

        elif choice==1:
            sourceAccount=input('enter savings or something else')
            phone=input('enter phone number:')
            Amount=float(input('enter amount MKW:'))
            balance['balance'] -=Amount
            print(f' you have purchased airtime of MKW.{Amount} to {phone} successfully')
        elif choice==3:
            print('exit program')
            break
        else:
            print('invalid option')

# %%
def my_profile():
    print('\n==change pins==')
    T_pin=int(input('enter new t_pin'))
    M_pin=int(input('enter new M_pin'))
    pins={'T-pin':T_pin,'M_pin':M_pin}
    print('pins changed')

# %%
def main_manu():
    M_pin=int(input('enter your M_pin'))
    if M_pin==3333:
        while True:
            print('1.deposit money')
            print('2.my profile')
            print('3.loan')
            print('4.withdrawal')
            print('5.my_account')
            print('6.money transfer')
            print('7.create_account')
            print('8.payments')
            print('9.top_up')
            print('10.exit program')
            option=int(input('enter your option'))
            if option==1:
                deposit()
            elif option==2:
                my_profile()
            elif option==3:
                loan()
            elif option==4:
                withdrawal()
            elif option==5:
                my_account()
            elif option==6:
                money_transfer()
            elif option==7:
                create_account()
            elif option==8:
                payments()
            elif option==9:
                top_up()
            elif option==10:
                print('program exited')
                break
    else:
        print('you have entered an invalid M_pin!')

# %%
main_manu()
# Out:
# enter your M_pin 3333
# 1.deposit money
# 2.my profile
# 3.loan
# 4.withdrawal
# 5.my_account
# 6.money transfer
# 7.create_account
# 8.payments
# 9.top_up
# 10.exit program
# enter your option 9
# 1.Airtel
# 2.TNM
# 3.exit program
# enter your choice 1
# enter savings or something else w
# enter phone number: 8
# enter amount MKW: 6666
#  you have purchased airtime of MKW.6666.0 to 8 successfully
# 1.Airtel
# 2.TNM
# 3.exit program
# enter your choice 3
# exit program
# 1.deposit money
# 2.my profile
# 3.loan
# 4.withdrawal
# 5.my_account
# 6.money transfer
# 7.create_account
# 8.payments
# 9.top_up
# 10.exit program
# enter your option 10
# program exited
